# %% [markdown]
# # Packages

# %% [markdown]
# **Import**

# %%
import random

# %%
import math

# %%
import string

# %%
import keyword

# %%
import time

# %%
import cv2

# %%
import pygame
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
random
# Out:
# <module 'random' from 'D:\\anaconda\\Lib\\random.py'>

# %%
cv2
# Out:
# <module 'cv2' from 'C:\\Users\\LENOVO\\AppData\\Roaming\\Python\\Python311\\site-packages\\cv2\\__init__.py'>

# %% [markdown]
# **dir**

# %%
import random
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '_Set',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_log',
#  '_os',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate']

# %% [markdown]
# ***help***

# %%
# help(package name.method name)
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %% [markdown]
# # import package name
# # step-2: dir(package_name)
# # step-3: help(package name.method name)
# # step-4: random.method(a,b)

# %%
import random
dir(random)
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(20,30)
# Out:
# 20

# %%
import random
dir(random)
help(random.gauss)
random.gauss()
# Out:
# Help on built-in function random:
#
# random() method of random.Random instance
#     random() -> x in the interval [0, 1).
# 0.040753594699349804

# %%
import random
random.randrange(2,20,3)
# 2 3 4 5 6 7 8 9 10
#2 5 8 (From the range 2 to 10)
# from the above no we will get random no from it.
# Out:
# 11

# %%
import random
print(random.randint(1,10))
print(random.random())
print(random.randrange(1,20,5))
# Out:
# 3
# 0.566224756078393
# 11

# %%
import math
dir (math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
import math
dir (math)
math.pow(2,3)
# Out:
# 8.0

# %%
math.sqrt(2)
# Out:
# 1.4142135623730951

# %%
print(round(math.pi,3))
print(math.sin(0))
print(math.cos(0))
# Out:
# 3.142
# 0.0
# 1.0

# %%
import keyword
dir(keyword)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'iskeyword',
#  'issoftkeyword',
#  'kwlist',
#  'softkwlist']

# %%
import keyword
dir(keyword)
keyword.kwlist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 import keyword
#       2 dir(keyword)
# ----> 3 keyword.kwlist()
#
# TypeError: 'list' object is not callable

# %%
import time
dir (time)
# Out:
# ['_STRUCT_TM_ITEMS',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'altzone',
#  'asctime',
#  'ctime',
#  'daylight',
#  'get_clock_info',
#  'gmtime',
#  'localtime',
#  'mktime',
#  'monotonic',
#  'monotonic_ns',
#  'perf_counter',
#  'perf_counter_ns',
#  'process_time',
#  'process_time_ns',
#  'sleep',
#  'strftime',
#  'strptime',
#  'struct_time',
#  'thread_time',
#  'thread_time_ns',
#  'time',
#  'time_ns',
#  'timezone',
#  'tzname']

# %%
import time
time.sleep(5)
print("hello")
# Out:
# hello

# %% [markdown]
# # assigment- String package

# %%
import string
dir (string)
# Out:
# ['Formatter',
#  'Template',
#  '_ChainMap',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_re',
#  '_sentinel_dict',
#  '_string',
#  'ascii_letters',
#  'ascii_lowercase',
#  'ascii_uppercase',
#  'capwords',
#  'digits',
#  'hexdigits',
#  'octdigits',
#  'printable',
#  'punctuation',
#  'whitespace']

# %%
string.ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
import string
num="jai"
help(string.hexdigits)
string.hexdigits(str(num))
# Out:
# No Python documentation found for '0123456789abcdefABCDEF'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       2 num="jai"
#       3 help(string.hexdigits)
# ----> 4 string.hexdigits(str(num))
#
# TypeError: 'str' object is not callable

# %%
string.capwords("jaideep gandi ")

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import cv2
dir (cv2)
# Out:
# ['ACCESS_FAST',
#  'ACCESS_MASK',
#  'ACCESS_READ',
#  'ACCESS_RW',
#  'ACCESS_WRITE',
#  'ADAPTIVE_THRESH_GAUSSIAN_C',
#  'ADAPTIVE_THRESH_MEAN_C',
#  'AGAST_FEATURE_DETECTOR_AGAST_5_8',
#  'AGAST_FEATURE_DETECTOR_AGAST_7_12D',
#  'AGAST_FEATURE_DETECTOR_AGAST_7_12S',
#  'AGAST_FEATURE_DETECTOR_NONMAX_SUPPRESSION',
#  'AGAST_FEATURE_DETECTOR_OAST_9_16',
#  'AGAST_FEATURE_DETECTOR_THRESHOLD',
#  'AKAZE',
#  'AKAZE_DESCRIPTOR_KAZE',
#  'AKAZE_DESCRIPTOR_KAZE_UPRIGHT',
#  'AKAZE_DESCRIPTOR_MLDB',
#  'AKAZE_DESCRIPTOR_MLDB_UPRIGHT',
#  'AKAZE_create',
#  'AffineFeature',
#  'AffineFeature_create',
#  'AgastFeatureDetector',
#  'AgastFeatureDetector_AGAST_5_8',
#  'AgastFeatureDetector_AGAST_7_12d',
#  'AgastFeatureDetector_AGAST_7_12s',
#  'AgastFeatureDetector_NONMAX_SUPPRESSION',
#  'AgastFeatureDetector_OAST_9_16',
#  'AgastFeatureDetector_THRESHOLD',
#  'AgastFeatureDetector_create',
#  'Algorithm',
#  'AlignExposures',
#  'AlignMTB',
#  'AsyncArray',
#  'BFMatcher',
# ...

# %%
cv2.__version__
# Out:
# '4.9.0'

# %%
import random
n1=random.randint(1,100)
n2=random.randint(1,100)
n3=random.randint(1,100)
avg=n1+n2+n3/3
print(avg)
# Out:
# 92.66666666666667

# %%
pip install Flask
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import flask
dir(flask)
# Out:
# ['Blueprint',
#  'Config',
#  'Flask',
#  'Markup',
#  'Request',
#  'Response',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'abort',
#  'after_this_request',
#  'app',
#  'appcontext_popped',
#  'appcontext_pushed',
#  'appcontext_tearing_down',
#  'before_render_template',
#  'blueprints',
#  'cli',
#  'config',
#  'copy_current_request_context',
#  'ctx',
#  'current_app',
#  'escape',
#  'flash',
#  'g',
#  'get_flashed_messages',
#  'get_template_attribute',
#  'globals',
#  'got_request_exception',
#  'has_app_context',
#  'has_request_context',
#  'helpers',
#  'json',
#  'jsonify',
#  'logging',
#  'make_response',
#  'message_flashed',
#  'redirect',
#  'render_template',
#  'render_template_string',
#  'request',
#  'request_finished',
#  'request_started',
#  'request_tearing_down',
#  'scaffold',
#  'send_file',
# ...
